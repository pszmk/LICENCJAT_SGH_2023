# %%
import pandas as pd
from sklearn import tree
from sklearn.model_selection import train_test_split
# from sklearn.utils.random import sample_without_replacement

# %%
studentInfo_DDDJ_v1 = pd.read_csv('../data/studentInfo_DDDJ_v1.csv')

# %%
studentInfo_DDDJ_v1.head()
# Out:
#    id_student code_module code_presentation gender                region  \
# 0       28046         DDD             2013J      F      Yorkshire Region
# 1       29411         DDD             2013J      M  East Midlands Region
# 2       33930         DDD             2013J      F     South West Region
# 3       40184         DDD             2013J      M                 Wales
# 4       40563         DDD             2013J      F     South East Region
#
#        highest_education imd_band age_band  studied_credits disability  \
# 0       HE Qualification    10-20    35-55               70          N
# 1  A Level or Equivalent   80-90%     0-35               60          N
# 2  A Level or Equivalent   20-30%     0-35               90          N
# 3       HE Qualification   30-40%     55<=               60          N
# 4  A Level or Equivalent    0-10%     0-35               60          N
#
#   final_result  date_submitted  score
# 0         Fail           237.0   40.0
# 1         Pass           237.0   62.0
# 2         Pass           237.0   67.0
# 3  Distinction           241.0  100.0
# 4         Pass           237.0   49.0

# %%
studentInfo_DDDJ_v1.region.value_counts()
# Out:
# South Region            192
# Scotland                190
# East Anglian Region     179
# South West Region       149
# London Region           138
# North Western Region    137
# South East Region       122
# North Region            118
# West Midlands Region    114
# East Midlands Region    108
# Yorkshire Region        106
# Wales                    80
# Ireland                  50
# Name: region, dtype: int64

# %%
studentInfo_DDDJ_v1.drop(columns=['code_module'], inplace=True)

# %%
studentInfo_train_X, studentInfo_test_X, studentInfo_train_y, studentInfo_test_y = sklearn.model_selection.train_test_split(studentInfo_DDDJ_v1.drop(columns=['final_result', 'score']), studentInfo_DDDJ_v1[['final_result']], train_size=0.9, random_state=42, shuffle=True, stratify=None)

# %%
display(studentInfo_train_X.head())
display(studentInfo_train_y.head())
# Out:
#       id_student code_module code_presentation gender               region  \
# 1346      679897         DDD             2014J      F        London Region
# 1146      641896         DDD             2014J      F             Scotland
# 526       563016         DDD             2013J      M     Yorkshire Region
# 51        134243         DDD             2014J      F  East Anglian Region
# 425       531646         DDD             2014J      M         South Region
#
#           highest_education imd_band age_band  studied_credits disability  \
# 1346     Lower Than A Level   50-60%     0-35              120          N
# 1146  A Level or Equivalent   30-40%    35-55               60          N
# 526        HE Qualification   80-90%     55<=               60          N
# 51    A Level or Equivalent   80-90%     0-35               90          N
# 425      Lower Than A Level   80-90%     0-35               60          N
#
#       date_submitted
# 1346           242.0
# 1146           242.0
# 526            237.0
# 51             243.0
# 425            243.0
#      final_result
# 1346         Pass
# 1146         Pass
# 526          Pass
# 51           Pass
# 425          Fail

# %%
 dt_1 = tree.DecisionTreeClassifier(criterion='gini',
                                    splitter='best',
                                    max_depth=None,
                                    min_samples_split=2,
                                    min_samples_leaf=1,
                                    min_weight_fraction_leaf=0.0,
                                    max_features=None,
                                    random_state=None,
                                    max_leaf_nodes=None,
                                    min_impurity_decrease=0.0,
                                    class_weight=None,
                                    ccp_alpha=0.0)

# %%
dt_1.fit(studentInfo_train_X, studentInfo_train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 dt_1.fit(studentInfo_train_X, studentInfo_train_y)
#
# File ~/LIC_2023/LICENCJAT_SGH_2023/LICENCJAT_SGH_2023-venv/lib/python3.10/site-packages/sklearn/tree/_classes.py:889, in DecisionTreeClassifier.fit(self, X, y, sample_weight, check_input)
#     859 def fit(self, X, y, sample_weight=None, check_input=True):
#     860     """Build a decision tree classifier from the training set (X, y).
#     861
#     862     Parameters
#    (...)
#     886         Fitted estimator.
#     887     """
# --> 889     super().fit(
#     890         X,
#     891         y,
#     892         sample_weight=sample_weight,
#     893         check_input=check_input,
#     894     )
#     895     return self
#
# File ~/LIC_2023/LICENCJAT_SGH_2023/LICENCJAT_SGH_2023-venv/lib/python3.10/site-packages/sklearn/tree/_classes.py:186, in BaseDecisionTree.fit(self, X, y, sample_weight, check_input)
#     184 check_X_params = dict(dtype=DTYPE, accept_sparse="csc")
#     185 check_y_params = dict(ensure_2d=False, dtype=None)
# --> 186 X, y = self._validate_data(
#     187     X, y, validate_separately=(check_X_params, check_y_params)
#     188 )
#     189 if issparse(X):
#     190     X.sort_indices()
#
# File ~/LIC_2023/LICENCJAT_SGH_2023/LICENCJAT_SGH_2023-venv/lib/python3.10/site-packages/sklearn/base.py:579, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     577 if "estimator" not in check_X_params:
#     578     check_X_params = {**default_check_params, **check_X_params}
# --> 579 X = check_array(X, input_name="X", **check_X_params)
#     580 if "estimator" not in check_y_params:
#     581     check_y_params = {**default_check_params, **check_y_params}
#
# File ~/LIC_2023/LICENCJAT_SGH_2023/LICENCJAT_SGH_2023-venv/lib/python3.10/site-packages/sklearn/utils/validation.py:879, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     877         array = xp.astype(array, dtype, copy=False)
#     878     else:
# --> 879         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     880 except ComplexWarning as complex_warning:
#     881     raise ValueError(
#     882         "Complex data not supported\n{}\n".format(array)
#     883     ) from complex_warning
#
# File ~/LIC_2023/LICENCJAT_SGH_2023/LICENCJAT_SGH_2023-venv/lib/python3.10/site-packages/sklearn/utils/_array_api.py:185, in _asarray_with_order(array, dtype, order, copy, xp)
#     182     xp, _ = get_namespace(array)
#     183 if xp.__name__ in {"numpy", "numpy.array_api"}:
#     184     # Use NumPy API to support order
# --> 185     array = numpy.asarray(array, order=order, dtype=dtype)
#     186     return xp.asarray(array, copy=copy)
#     187 else:
#
# File ~/LIC_2023/LICENCJAT_SGH_2023/LICENCJAT_SGH_2023-venv/lib/python3.10/site-packages/pandas/core/generic.py:2070, in NDFrame.__array__(self, dtype)
#    2069 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
# -> 2070     return np.asarray(self._values, dtype=dtype)
#
# ValueError: could not convert string to float: 'DDD'
